# %% [markdown]
# # Problem Statement -
#
# We have a dataset of hotel bookings that includes both city hotels and resort hotels. In recent years, we have observed a high cancellation rate for bookings in both types of hotels. Our goal is to analyze the dataset to identify the factors contributing to the high cancellation rates and suggest improvements to mitigate these cancellations

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_csv("C:\\Users\\RAM\\Desktop\\kartik\\hotel_bookings 2.csv")

# %% [markdown]
# ## Exploratory Data Analysis And Data Cleaning

# %%
## top 5 rows also we can see more data to add the number.

df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
## last 5 rows ,also we can see more data to add number .

df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
## total number and columns present in our dataset 

df.shape
# Out:
# (119390, 32)

# %%
## 0 - represent Hotel is  not canceled and 1 represent is  canceled 

df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
### with help of info() ,we will check which type of data present in our dataset.in columns number 24 we have less number of null values 
## non null - True and Null - empty 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
## we have a columns " reservation_status_date " main columns for EDA .have in object form to we have to change date time format 

df['reservation_status_date']= pd.to_datetime(df['reservation_status_date'])

# %%
## use describe to check for statstical data its use for both numeric and object series.
## include basically use for to chcek specific category
df.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
## to exact the object type values in our dataframe with help of for loop.

for col in df.describe(include='object').columns:
    print(col)
    print(df[col].unique())
    print('_'*50) ## for use sepration more visual
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# __________________________________________________
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# __________________________________________________
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# __________________________________________________
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
# ...

# %%
## we will use isnull() with sum to check missing values in all columns 
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
## we will remove comany and agent columns and we will remove missing values in country and childern bcz its less amount .

df.drop (['company','agent'],axis=1 ,inplace =True) ## axis =1 use for columns remove and inplace use for missing values 
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df['adr'].plot(kind='box') ## in adr (average daily rate- one value is very high can say its outliar)
# Out:
# <Axes: >

# %%
df=df[df['adr']<5000] ## treat outliar

# %% [markdown]
# ## Data Analysis and Visulization
#
# a countplot to visualize the number of reservations in different hotels,categorized by their cancellation status. It customizes various aspects of the plot such as size,legend, title, and axis labels to improve readability and interpretation.

# %%
## uses bar plot because our columns in categorical
cancelled_perc = df['is_canceled'].value_counts(normalize=True)
print(cancelled_perc)

plt.figure(figsize=(5,4))
plt.title('reservation status count')
plt.bar(['not canceled','canceled'], df['is_canceled'].value_counts(),edgecolor='k',width=0.7)
# Out:
# 0    0.629584
# 1    0.370416
# Name: is_canceled, dtype: float64
# <BarContainer object of 2 artists>

# %% [markdown]
# ## summary
#
# The accompanying bar graph shows the percentage of reservation that are canceled and those that are not .is obvious that there is a significant number of reservations that have not canceled. there are still 37% of clients who canceled their reservations, which has a significant significant impact of hotel earnings.

# %%
## we will calcualte the percentage of of cancelation and non cancelation reservation 
cancelled_perc = df['is_canceled'].value_counts(normalize=True)
cancelled_perc
# Out:
# 0    0.629584
# 1    0.370416
# Name: is_canceled, dtype: float64

# %%
## with the help of count plot we will visulaize the canceltion and not cancelation in both hotels 

plt.figure(figsize=(8, 4))
ax = sns.countplot(x='hotel', hue='is_canceled', data=df, palette='Blues')
legend_labels, _ = ax.get_legend_handles_labels() ## handles represnt the grpahicalelements(bar) and labels categories
ax.legend(legend_labels, ['Not Canceled', 'Canceled'], bbox_to_anchor=(1, 1)) ## bbox_to_anchor=(1, 1)) -represnt postion
plt.title('Reservation Status in Different Hotels', size=20) ## represnt titles with the front size 
plt.xlabel('Hotel')
plt.ylabel('Number of Reservations')
plt.show()

# %% [markdown]
# ## summary
# In Comparison of Resort hotels, City hotel Have More bookings. it’s Possible that Resort hotels is more expensive than those in cities

# %%
## we can calculate individual canceliation or not cancelition 
resort_hotel = df[df['hotel'] == 'Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.722366
# 1    0.277634
# Name: is_canceled, dtype: float64

# %%
city_hotel = df[df['hotel'] == 'Resort Hotel']
city_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.722366
# 1    0.277634
# Name: is_canceled, dtype: float64

# %%
#### we will check the price effect of hotel canceliation 
## we will use mean of Adr ( average daily rate ) with the help of group by 
resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel =   city_hotel.groupby('reservation_status_date')[['adr']].mean()

plt.figure(figsize=(20, 8))
plt.title('Average daily rate of city and resort hotel', fontsize=30)
plt.plot(resort_hotel.index, resort_hotel['adr'], label='Resort Hotel')
plt.plot(city_hotel.index, city_hotel['adr'], label='City Hotel')
plt.legend(fontsize=15)
plt.show()

# %% [markdown]
# ## output
#
# The line graph above shows that, on certain days the average daily rate of city hotel is less than that of resort hotel, and on other days, it’s even less. Its goes without saying that weekdays and holidays may see a rise in resort hotel rates.

# %%
### We will create a count bar plot to analyze the monthly reservations and cancellations.


df['month'] = df['reservation_status_date']. dt.month
plt.figure(figsize=(16, 8))
ax1 = sns.countplot(x='month', hue='is_canceled', data=df, palette='bright')
legend_labels, _ = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1, 1))
plt.title('Reservation Status per Month', size=20)
plt.xlabel('Month')
plt.ylabel('Number of Reservations')
plt.legend(['Not Canceled', 'Canceled'])
plt.show()

# %% [markdown]
# ## output
#
# We have developed the grouped bar graph to analyses the months with the highest and lowest reservations level according to reservations status. As can be seen, both the number of canceled reservations are largest in the month of August. whereas January is the month with the most canceled reservations.

# %%
## in above visulaize we can see in jan month the cancelattion is very high so with the help of barplot 
# we will check whether due to price the cancelation is affected or not 


import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))
plt.title('ADR for Each Month', fontsize=30)
sns.barplot(x='month', y='adr', data=df[df['is_canceled'] == 1].groupby('month')[['adr']].sum().reset_index())
plt.xlabel('Month')
plt.ylabel('Average Daily Rate (ADR)')
plt.show()

# %% [markdown]
# ## output
# The bar graph demonstrates that cancelations are most common that when prices are greatest and are least common that when they are lowest. Therefore, the cost of the accommodation is solely responsible for the cancelation.

# %% [markdown]
# ## output
# in above visual we have seen that in january month the price was  very high so cancelation was very high ,cancelation is directly affected by price .

# %%
## we will find out the cancelation  base on top 10 countries 


cancelled_data = df[df['is_canceled'] == 1]
top_10_countries = cancelled_data['country'].value_counts().head(10)
plt.figure(figsize=(8, 8))
plt.title('Top 10 Countries with Reservation Canceled')
plt.pie(top_10_countries, autopct='%.2f%%', labels=top_10_countries.index)
plt.show()

# %% [markdown]
# ## Now,
# let’s see which country has the highest reservations canceled. The top Country is the Portugal with the highest number of cancelations.

# %%
## we will use Correlation with the help of heatmap to check for correlation of each columns .

plt.figure(figsize=(15, 10))
sns.heatmap(df.corr(numeric_only=True), annot=True) ## setting the only numeric only columns true to avoid warnings.
plt.title('Correlation of the Columns', fontsize=20)
plt.show()

# %% [markdown]
#  ## we have observed that with  the help of above heatmap
# 1-lead_time and total_stay is postively correlated that means if customers stay more then lead time increases.
# 2-Adults ,childern and babies are correlated to each other.that means more the people more will be adr .
# 3- is repeated guests and previous bookings not canceled has strong correlation .that means reapted guests don't cancel the bookings .

# %%
## we will find out our client coming from online/ offline travel

df['market_segment'].value_counts()
# Out:
# Online TA        56477
# Offline TA/TO    24219
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: market_segment, dtype: int64

# %%
df['market_segment'].value_counts(normalize='True')
# Out:
# Online TA        0.473046
# Offline TA/TO    0.202856
# Groups           0.165935
# Direct           0.105587
# Corporate        0.044350
# Complementary    0.006223
# Aviation         0.001985
# Undefined        0.000017
# Name: market_segment, dtype: float64

# %% [markdown]
# ## summary
#
# Let’s check the area from where guests visiting the hotels and making reservations. Is its coming from direct or groups, online or offline Travel Agents? Around 47% clients from online travel agencies, whereas 16% from groups. Only 10% of the client’s book hotels directly by visiting them and making reservations

# %%
## we will calculate the percentage of cancelation in the online reservation 

cancelled_data['market_segment'].value_counts(normalize='True')
# Out:
# Online TA        0.468954
# Groups           0.273539
# Offline TA/TO    0.187930
# Direct           0.043732
# Corporate        0.022431
# Complementary    0.002193
# Aviation         0.001176
# Undefined        0.000045
# Name: market_segment, dtype: float64

# %% [markdown]
# ## Summary
#
# Let's examine the areas with high cancellation rates. Approximately 47% of cancellations occur online, 27% occur in group reservations, and only 4% occur through direct cancellations.

# %%
## we will check the price of hotel  whether its cancelation or not cancelation 
cancelled_df_adr = cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace=True)
cancelled_df_adr.sort_values('reservation_status_date', inplace=True)

not_cancelled_data = df[df['is_canceled'] == 0]

not_cancelled_df_adr = not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace=True)
not_cancelled_df_adr.sort_values('reservation_status_date', inplace=True)

plt.figure(figsize=(20, 6))
plt.title('Average Daily Rate')
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label='not_cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label='cancelled')
plt.legend()
plt.show()

# %%
## ## in above visual data is not consistent to we will filter the data 2016 to 2017-09

cancelled_df_adr = cancelled_data[cancelled_data['reservation_status_date'].between('2016', '2017-09')]
cancelled_df_adr = cancelled_df_adr.groupby('reservation_status_date')[['adr']].mean().reset_index()

not_cancelled_df_adr = not_cancelled_data[not_cancelled_data['reservation_status_date'].between('2016', '2017-09')]
not_cancelled_df_adr = not_cancelled_df_adr.groupby('reservation_status_date')[['adr']].mean().reset_index()

plt.figure(figsize=(20, 6))
plt.title('Average Daily Rate',fontsize =30)
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label='not_cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label='cancelled')
plt.legend()
plt.show()

# %% [raw]
# As seen in the Graph, reservations are canceled when the average daily rate higher then when it’s not canceled. It clearly proves all the above analysis, that the higher price leads to higher cancelation.

# %% [markdown]
# ## Suggestions.
#
#  1-	Cancellations rates rise as the price does. In order to prevent cancelations of reservations. Hotels could work of pricing strategies and try to lower the rates for the specific hotels based on the locations. They can also provide some discount to the consumers.
#
#  2-	As the Ratio of cancellation and not cancellation of the resort hotel is higher in resort hotel then the city hotels. So hotel should provide reasonable discount on the room prices on weekends or on hotels.
#
#  3-	In the month of January can start campaigns or marketing with reasonable Amount to increase their revenue as the cancellation is the highest in this month.
#
#  4-	They can increase the Quality of their hotels and their services mainly in Portugal to Reduce the cancellation rate.
